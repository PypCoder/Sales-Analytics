# %%
import pandas as pd
import matplotlib.pyplot as plt
import openpyxl
from openpyxl import Workbook
from openpyxl.drawing.image import Image
from openpyxl import load_workbook

wb = Workbook()
ws = wb.active

# %%
df=pd.read_excel("Superstore_data.xlsx")

# %%
df.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# 0       42420   South  FUR-BO-10001798        Furniture    Bookcases
# 1       42420   South  FUR-CH-10000454        Furniture       Chairs
# 2       90036    West  OFF-LA-10000240  Office Supplies       Labels
# 3       33311   South  FUR-TA-10000577        Furniture       Tables
# 4       33311   South  OFF-ST-10000760  Office Supplies      Storage
#
#                                         Product Name     Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.9600         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400         3
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200         2
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775         5
# 4                     Eldon Fold 'N Roll Cart System   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# 3      0.45 -383.0310
# 4      0.20    2.5164
#
# [5 rows x 21 columns]

# %%
df.describe()
# Out:
#             Row ID                     Order Date  \
# count  9994.000000                           9994
# mean   4997.500000  2016-04-30 00:07:12.259355648
# min       1.000000            2014-01-03 00:00:00
# 25%    2499.250000            2015-05-23 00:00:00
# 50%    4997.500000            2016-06-26 00:00:00
# 75%    7495.750000            2017-05-14 00:00:00
# max    9994.000000            2017-12-30 00:00:00
# std    2885.163629                            NaN
#
#                            Ship Date   Postal Code         Sales     Quantity  \
# count                           9994   9994.000000   9994.000000  9994.000000
# mean   2016-05-03 23:06:58.571142912  55190.379428    229.858001     3.789574
# min              2014-01-07 00:00:00   1040.000000      0.444000     1.000000
# 25%              2015-05-27 00:00:00  23223.000000     17.280000     2.000000
# 50%              2016-06-29 00:00:00  56430.500000     54.490000     3.000000
# 75%              2017-05-18 00:00:00  90008.000000    209.940000     5.000000
# max              2018-01-05 00:00:00  99301.000000  22638.480000    14.000000
# std                              NaN  32063.693350    623.245101     2.225110
#
#           Discount       Profit
# count  9994.000000  9994.000000
# mean      0.156203    28.656896
# min       0.000000 -6599.978000
# 25%       0.000000     1.728750
# 50%       0.200000     8.666500
# 75%       0.200000    29.364000
# max       0.800000  8399.976000
# std       0.206452   234.260108

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
sorted_col=[]
for col in df.columns:
    sorted_col.append(df[col].is_monotonic_increasing)
print("Sorted Columns:", sorted_col )
# Out:
# Sorted Columns: [True, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False]

# %%
sorted_col=[]
for col in df.columns:
    sorted_col.append(df[col].is_monotonic_decreasing)
print("Sorted Columns:", sorted_col )
# Out:
# Sorted Columns: [False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False]

# %%
df.sort_values(by="Order Date",ascending=False,inplace=True)

# %%
df.dtypes
# Out:
# Row ID                    int64
# Order ID                 object
# Order Date       datetime64[ns]
# Ship Date        datetime64[ns]
# Ship Mode                object
# Customer ID              object
# Customer Name            object
# Segment                  object
# Country                  object
# City                     object
# State                    object
# Postal Code               int64
# Region                   object
# Product ID               object
# Category                 object
# Sub-Category             object
# Product Name             object
# Sales                   float64
# Quantity                  int64
# Discount                float64
# Profit                  float64
# dtype: object

# %%
df
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2017-143259 2017-12-30 2018-01-03  Standard Class
# 1          2  CA-2017-143259 2017-12-30 2018-01-03  Standard Class
# 2          3  CA-2017-115427 2017-12-30 2018-01-03  Standard Class
# 3          4  CA-2017-115427 2017-12-30 2018-01-03  Standard Class
# 4          5  CA-2017-126221 2017-12-30 2018-01-05  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2014-141817 2014-01-05 2014-01-12  Standard Class
# 9990    9991  CA-2014-112326 2014-01-04 2014-01-08  Standard Class
# 9991    9992  CA-2014-112326 2014-01-04 2014-01-08  Standard Class
# 9992    9993  CA-2014-112326 2014-01-04 2014-01-08  Standard Class
# 9993    9994  CA-2014-103800 2014-01-03 2014-01-07  Standard Class
#
#      Customer ID      Customer Name      Segment        Country  \
# 0       PO-18865  Patrick O'Donnell     Consumer  United States
# 1       PO-18865  Patrick O'Donnell     Consumer  United States
# 2       EB-13975         Erica Bern    Corporate  United States
# 3       EB-13975         Erica Bern    Corporate  United States
# 4       CC-12430        Chuck Clark  Home Office  United States
# ...          ...                ...          ...            ...
# 9989    MB-18085         Mick Brown     Consumer  United States
# 9990    PO-19195      Phillina Ober  Home Office  United States
# 9991    PO-19195      Phillina Ober  Home Office  United States
# 9992    PO-19195      Phillina Ober  Home Office  United States
# 9993    DP-13000      Darren Powers     Consumer  United States
#
#                City  ...   Region       Product ID         Category  \
# 0     New York City  ...     East  FUR-BO-10003441        Furniture
# 1     New York City  ...     East  TEC-PH-10004774       Technology
# 2         Fairfield  ...     West  OFF-BI-10002103  Office Supplies
# 3         Fairfield  ...     West  OFF-BI-10004632  Office Supplies
# 4          Columbus  ...  Central  OFF-AP-10002457  Office Supplies
# ...             ...  ...      ...              ...              ...
# 9989   Philadelphia  ...     East  OFF-AR-10003478  Office Supplies
# 9990     Naperville  ...  Central  OFF-BI-10004094  Office Supplies
# 9991     Naperville  ...  Central  OFF-LA-10003223  Office Supplies
# 9992     Naperville  ...  Central  OFF-ST-10002743  Office Supplies
# 9993        Houston  ...  Central  OFF-PA-10000174  Office Supplies
#
#      Sub-Category                                       Product Name    Sales  \
# 0       Bookcases  Bush Westfield Collection Bookcases, Fully Ass...  323.136
# 1          Phones                          Gear Head AU3700S Headset   90.930
# 2         Binders    Cardinal Slant-D Ring Binder, Heavy Gauge Vinyl   13.904
# 3         Binders                                 GBC Binding covers   20.720
# 4      Appliances  Eureka The Boss Plus 12-Amp Hard Box Upright V...  209.300
# ...           ...                                                ...      ...
# 9989          Art  Avery Hi-Liter EverBold Pen Style Fluorescent ...   19.536
# 9990      Binders         GBC Standard Plastic Binding Systems Combs    3.540
# 9991       Labels                                          Avery 508   11.784
# 9992      Storage                      SAFCO Boltless Steel Shelving  272.736
# 9993        Paper  Message Book, Wirebound, Four 5 1/2" X 4" Form...   16.448
#
#      Quantity  Discount   Profit  Profit Margin
# 0           4       0.2  12.1176         0.0375
# 1           7       0.0   2.7279         0.0300
# 2           2       0.2   4.5188         0.3250
# 3           2       0.2   6.4750         0.3125
# 4           2       0.0  56.5110         0.2700
# ...       ...       ...      ...            ...
# 9989        3       0.2   4.8840         0.2500
# 9990        2       0.8  -5.4870        -1.5500
# 9991        3       0.2   4.2717         0.3625
# 9992        3       0.2 -64.7748        -0.2375
# 9993        2       0.2   5.5512         0.3375
#
# [9994 rows x 22 columns]

# %%
df["Order Date"]=pd.to_datetime(df["Order Date"])
df["Ship Date"]=pd.to_datetime(df["Ship Date"])

# %%
df.dtypes
# Out:
# Row ID                    int64
# Order ID                 object
# Order Date       datetime64[ns]
# Ship Date        datetime64[ns]
# Ship Mode                object
# Customer ID              object
# Customer Name            object
# Segment                  object
# Country                  object
# City                     object
# State                    object
# Postal Code               int64
# Region                   object
# Product ID               object
# Category                 object
# Sub-Category             object
# Product Name             object
# Sales                   float64
# Quantity                  int64
# Discount                float64
# Profit                  float64
# dtype: object

# %%
df['Profit Margin']=df['Profit']/df['Sales']
df.reset_index(inplace=True)
for i in range(0,len(df)):
    df.loc[i,'Row ID']=i+1

# %%
df.pop('index')
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2017-143259 2017-12-30 2018-01-03  Standard Class
# 1          2  CA-2017-143259 2017-12-30 2018-01-03  Standard Class
# 2          3  CA-2017-115427 2017-12-30 2018-01-03  Standard Class
# 3          4  CA-2017-115427 2017-12-30 2018-01-03  Standard Class
# 4          5  CA-2017-126221 2017-12-30 2018-01-05  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2014-141817 2014-01-05 2014-01-12  Standard Class
# 9990    9991  CA-2014-112326 2014-01-04 2014-01-08  Standard Class
# 9991    9992  CA-2014-112326 2014-01-04 2014-01-08  Standard Class
# 9992    9993  CA-2014-112326 2014-01-04 2014-01-08  Standard Class
# 9993    9994  CA-2014-103800 2014-01-03 2014-01-07  Standard Class
#
#      Customer ID      Customer Name      Segment        Country  \
# 0       PO-18865  Patrick O'Donnell     Consumer  United States
# 1       PO-18865  Patrick O'Donnell     Consumer  United States
# 2       EB-13975         Erica Bern    Corporate  United States
# 3       EB-13975         Erica Bern    Corporate  United States
# 4       CC-12430        Chuck Clark  Home Office  United States
# ...          ...                ...          ...            ...
# 9989    MB-18085         Mick Brown     Consumer  United States
# 9990    PO-19195      Phillina Ober  Home Office  United States
# 9991    PO-19195      Phillina Ober  Home Office  United States
# 9992    PO-19195      Phillina Ober  Home Office  United States
# 9993    DP-13000      Darren Powers     Consumer  United States
#
#                City  ...   Region       Product ID         Category  \
# 0     New York City  ...     East  FUR-BO-10003441        Furniture
# 1     New York City  ...     East  TEC-PH-10004774       Technology
# 2         Fairfield  ...     West  OFF-BI-10002103  Office Supplies
# 3         Fairfield  ...     West  OFF-BI-10004632  Office Supplies
# 4          Columbus  ...  Central  OFF-AP-10002457  Office Supplies
# ...             ...  ...      ...              ...              ...
# 9989   Philadelphia  ...     East  OFF-AR-10003478  Office Supplies
# 9990     Naperville  ...  Central  OFF-BI-10004094  Office Supplies
# 9991     Naperville  ...  Central  OFF-LA-10003223  Office Supplies
# 9992     Naperville  ...  Central  OFF-ST-10002743  Office Supplies
# 9993        Houston  ...  Central  OFF-PA-10000174  Office Supplies
#
#      Sub-Category                                       Product Name    Sales  \
# 0       Bookcases  Bush Westfield Collection Bookcases, Fully Ass...  323.136
# 1          Phones                          Gear Head AU3700S Headset   90.930
# 2         Binders    Cardinal Slant-D Ring Binder, Heavy Gauge Vinyl   13.904
# 3         Binders                                 GBC Binding covers   20.720
# 4      Appliances  Eureka The Boss Plus 12-Amp Hard Box Upright V...  209.300
# ...           ...                                                ...      ...
# 9989          Art  Avery Hi-Liter EverBold Pen Style Fluorescent ...   19.536
# 9990      Binders         GBC Standard Plastic Binding Systems Combs    3.540
# 9991       Labels                                          Avery 508   11.784
# 9992      Storage                      SAFCO Boltless Steel Shelving  272.736
# 9993        Paper  Message Book, Wirebound, Four 5 1/2" X 4" Form...   16.448
#
#      Quantity  Discount   Profit  Profit Margin
# 0           4       0.2  12.1176         0.0375
# 1           7       0.0   2.7279         0.0300
# 2           2       0.2   4.5188         0.3250
# 3           2       0.2   6.4750         0.3125
# 4           2       0.0  56.5110         0.2700
# ...       ...       ...      ...            ...
# 9989        3       0.2   4.8840         0.2500
# 9990        2       0.8  -5.4870        -1.5500
# 9991        3       0.2   4.2717         0.3625
# 9992        3       0.2 -64.7748        -0.2375
# 9993        2       0.2   5.5512         0.3375
#
# [9994 rows x 22 columns]

# %%
profit_margin_agg_category=df.groupby('Category')['Profit Margin'].sum()

# %%
profit_margin_agg_sub_category=df.groupby('Sub-Category')['Profit Margin'].sum()

# %%
top_products_by_sales=df.groupby('Product Name')['Sales'].sum().nlargest(10)

# %%
top_customers_by_sales=df.groupby('Customer ID')['Sales'].sum().nlargest(10)

# %%
least_products_by_sales=df.groupby('Product Name')['Sales'].sum().nsmallest(10)

# %%
least_customers_by_sales=df.groupby('Customer ID')['Sales'].sum().nsmallest(10)

# %%
monthly_sales=df.set_index("Order Date").resample('ME')['Sales'].sum()
monthly_sales.index=monthly_sales.index.strftime('%B %Y')
monthly_sales_df=monthly_sales.reset_index()
monthly_sales_df.columns=['Month','Sales']

# %%
total_sales=df['Sales'].sum()

# %%
top_customers_by_profit=df.groupby('Customer ID')['Profit'].sum().nlargest(10)

# %%
least_customers_by_profit=df.groupby('Customer ID')['Profit'].sum().nsmallest(10)

# %%
top_products_by_profit=df.groupby('Product Name')['Profit'].sum().nlargest(10)

# %%
least_products_by_profit=df.groupby('Product Name')['Profit'].sum().nsmallest(10)

# %%
monthly_profits=df.set_index('Order Date').resample('ME')['Profit'].sum()
monthly_profits.index=monthly_profits.index.strftime('%B %Y')
monthly_profits_df=monthly_profits.reset_index()
monthly_profits_df.columns=['Month','Profits']

# %%
total_profit=df['Profit'].sum()

# %%
state_summary = df.groupby('State').agg({'Sales': 'sum', 'Profit': 'sum'}).sort_values(by='Sales', ascending=False)

# %%
pivot_table=df.pivot_table(values='Sales',index='Sub-Category',columns='Category',aggfunc='sum')

# %%
pivot_table.fillna('-',inplace=True)

# %%
def reset_df_index(graph_data):
    df2 = pd.DataFrame(graph_data)
    df2 = df2.reset_index()
    df2.columns = df2.columns
    return df2

def plot_graph(graph_data='',graph_type='',color=''):
    df2=reset_df_index(graph_data)
    print(df2)
    plt.figure(figsize=(6,6))
    graph_data.plot(kind=graph_type,color=color)
    plt.legend()
    #plt.savefig(f'{graph_data}.png')
    plt.show()
    with pd.ExcelWriter("Sorted_Superstore_extracted_data.xlsx",mode='a',engine=openpyxl) as f:
        df2.to_excel(f,sheet_name='Sheet1',index=False)
    #img = Image(f'{graph_data}.png')
    #ws.add_image(img)
    #wb.save('Sorted_Superstore_extracted_data.xlsx')

# %%
plot_graph(profit_margin_agg_category,'pie',color='black')
plot_graph(profit_margin_agg_sub_category,'barh',color=['red' if val<0 else 'green' for val in profit_margin_agg_sub_category])
plot_graph(top_products_by_sales,'barh',color='black')
plot_graph(top_products_by_profit,'barh',color='black')
plot_graph(top_customers_by_sales,'barh',color='black')
plot_graph(top_customers_by_profit,'barh',color='black')
plot_graph(least_products_by_sales,'barh',color='black')
plot_graph(least_products_by_profit,'barh',color='black')
plot_graph(least_customers_by_sales,'barh',color='black')
plot_graph(least_customers_by_profit,'barh',color='black')
# Out:
#           Category  Profit Margin
# 0        Furniture      82.259874
# 1  Office Supplies     831.770556
# 2       Technology     288.386984
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\io\excel\_util.py:93, in get_writer(engine_name)
#      92 try:
# ---> 93     return _writers[engine_name]
#      94 except KeyError as err:
#
# KeyError: <module 'openpyxl' from 'C:\\Users\\Dell\\AppData\\Local\\Packages\\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\\LocalCache\\local-packages\\Python312\\site-packages\\openpyxl\\__init__.py'>
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[287], line 1
# ----> 1 plot_graph(profit_margin_agg_category,'pie',color='black')
#       2 plot_graph(profit_margin_agg_sub_category,'barh',color=['red' if val<0 else 'green' for val in profit_margin_agg_sub_category])
#       3 plot_graph(top_products_by_sales,'barh',color='black')
#
# Cell In[284], line 15, in plot_graph(graph_data, graph_type, color)
#      13 #plt.savefig(f'{graph_data}.png')
#      14 plt.show()
# ---> 15 with pd.ExcelWriter("Sorted_Superstore_extracted_data.xlsx",mode='a',engine=openpyxl) as f:
#      16     df2.to_excel(f,sheet_name='Sheet1',index=False)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\io\excel\_base.py:1146, in ExcelWriter.__new__(cls, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs)
#    1143     assert engine is not None
#    1144     #  error: Incompatible types in assignment (expression has type
#    1145     #  "type[ExcelWriter[Any]]", variable has type "type[Self]")
# -> 1146     cls = get_writer(engine)  # type: ignore[assignment]
#    1148 return object.__new__(cls)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\io\excel\_util.py:95, in get_writer(engine_name)
#      93     return _writers[engine_name]
#      94 except KeyError as err:
# ---> 95     raise ValueError(f"No Excel writer '{engine_name}'") from err
#
# ValueError: No Excel writer '<module 'openpyxl' from 'C:\\Users\\Dell\\AppData\\Local\\Packages\\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\\LocalCache\\local-packages\\Python312\\site-packages\\openpyxl\\__init__.py'>'

# %%
plt.figure(figsize=(8,12))
plt.scatter(monthly_sales_df['Sales'],monthly_sales_df['Month'],color=['red' if val<0 else 'green' for val in monthly_sales])
print(monthly_sales_df)
plt.show()
plt.figure(figsize=(100,6))
plt.plot(monthly_sales)
plt.show()
plt.figure(figsize=(8,12))
plt.scatter(monthly_profits_df['Profits'],monthly_profits_df['Month'],color=['red' if val<0 else 'green' for val in monthly_profits])
print(monthly_sales_df)
plt.show()
plt.figure(figsize=(100,6))
plt.plot(monthly_profits)
print(monthly_profits_df)
plt.show()
# Out:
#              Month        Sales
# 0     January 2014   14236.8950
# 1    February 2014    4519.8920
# 2       March 2014   55691.0090
# 3       April 2014   28295.3450
# 4         May 2014   23648.2870
# 5        June 2014   34595.1276
# 6        July 2014   33946.3930
# 7      August 2014   27909.4685
# 8   September 2014   81777.3508
# 9     October 2014   31453.3930
# 10   November 2014   78628.7167
# 11   December 2014   69545.6205
# 12    January 2015   18174.0756
# 13   February 2015   11951.4110
# 14      March 2015   38726.2520
# 15      April 2015   34195.2085
# 16        May 2015   30131.6865
# 17       June 2015   24797.2920
# 18       July 2015   28765.3250
# 19     August 2015   36898.3322
# 20  September 2015   64595.9180
# 21    October 2015   31404.9235
# 22   November 2015   75972.5635
# 23   December 2015   74919.5212
# 24    January 2016   18542.4910
# 25   February 2016   22978.8150
# 26      March 2016   51715.8750
# 27      April 2016   38750.0390
# 28        May 2016   56987.7280
# 29       June 2016   40344.5340
# 30       July 2016   39261.9630
# 31     August 2016   31115.3743
# 32  September 2016   73410.0249
# 33    October 2016   59687.7450
# 34   November 2016   79411.9658
# 35   December 2016   96999.0430
# 36    January 2017   43971.3740
# 37   February 2017   20301.1334
# 38      March 2017   58872.3528
# 39      April 2017   36521.5361
# 40        May 2017   44261.1102
# 41       June 2017   52981.7257
# 42       July 2017   45264.4160
# 43     August 2017   63120.8880
# 44  September 2017   87866.6520
# 45    October 2017   77776.9232
# 46   November 2017  118447.8250
# 47   December 2017   83829.3188
#              Month        Sales
# 0     January 2014   14236.8950
# 1    February 2014    4519.8920
# 2       March 2014   55691.0090
# 3       April 2014   28295.3450
# 4         May 2014   23648.2870
# 5        June 2014   34595.1276
# 6        July 2014   33946.3930
# 7      August 2014   27909.4685
# 8   September 2014   81777.3508
# 9     October 2014   31453.3930
# 10   November 2014   78628.7167
# 11   December 2014   69545.6205
# 12    January 2015   18174.0756
# 13   February 2015   11951.4110
# 14      March 2015   38726.2520
# 15      April 2015   34195.2085
# 16        May 2015   30131.6865
# 17       June 2015   24797.2920
# 18       July 2015   28765.3250
# 19     August 2015   36898.3322
# 20  September 2015   64595.9180
# 21    October 2015   31404.9235
# 22   November 2015   75972.5635
# 23   December 2015   74919.5212
# 24    January 2016   18542.4910
# 25   February 2016   22978.8150
# 26      March 2016   51715.8750
# 27      April 2016   38750.0390
# 28        May 2016   56987.7280
# 29       June 2016   40344.5340
# 30       July 2016   39261.9630
# 31     August 2016   31115.3743
# 32  September 2016   73410.0249
# 33    October 2016   59687.7450
# 34   November 2016   79411.9658
# 35   December 2016   96999.0430
# 36    January 2017   43971.3740
# 37   February 2017   20301.1334
# 38      March 2017   58872.3528
# 39      April 2017   36521.5361
# 40        May 2017   44261.1102
# 41       June 2017   52981.7257
# 42       July 2017   45264.4160
# 43     August 2017   63120.8880
# 44  September 2017   87866.6520
# 45    October 2017   77776.9232
# 46   November 2017  118447.8250
# 47   December 2017   83829.3188
#              Month     Profits
# 0     January 2014   2450.1907
# 1    February 2014    862.3084
# 2       March 2014    498.7299
# 3       April 2014   3488.8352
# 4         May 2014   2738.7096
# 5        June 2014   4976.5244
# 6        July 2014   -841.4826
# 7      August 2014   5318.1050
# 8   September 2014   8328.0994
# 9     October 2014   3448.2573
# 10   November 2014   9292.1269
# 11   December 2014   8983.5699
# 12    January 2015  -3281.0070
# 13   February 2015   2813.8508
# 14      March 2015   9732.0978
# 15      April 2015   4187.4962
# 16        May 2015   4667.8690
# 17       June 2015   3335.5572
# 18       July 2015   3288.6483
# 19     August 2015   5355.8084
# 20  September 2015   8209.1627
# 21    October 2015   2817.3660
# 22   November 2015  12474.7884
# 23   December 2015   8016.9659
# 24    January 2016   2824.8233
# 25   February 2016   5004.5795
# 26      March 2016   3611.9680
# 27      April 2016   2977.8149
# 28        May 2016   8662.1464
# 29       June 2016   4750.3781
# 30       July 2016   4432.8779
# 31     August 2016   2062.0693
# 32  September 2016   9328.6576
# 33    October 2016  16243.1425
# 34   November 2016   4011.4075
# 35   December 2016  17885.3093
# 36    January 2017   7140.4391
# 37   February 2017   1613.8720
# 38      March 2017  14751.8915
# 39      April 2017    933.2900
# 40        May 2017   6342.5828
# 41       June 2017   8223.3357
# 42       July 2017   6952.6212
# 43     August 2017   9040.9557
# 44  September 2017  10991.5556
# 45    October 2017   9275.2755
# 46   November 2017   9690.1037
# 47   December 2017   8483.3468

# %%
df.to_excel('Sorted_Superstore_data.xlsx',index=False)
